# %% [markdown]
# To download Python visit: https://www.python.org/downloads/

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Why Python ?</p><br>
# <h3><li>Python is a good general-purpose, high-level language.<br><br>
# <li>It is interpreted language.<br><br>
# <li>It is a scripting language.<br><br>
# <li>Its design makes it very readable, which is more important than it sounds.<br><br>
# <li>Uses an elegant syntax, making the programs you write easier to read.<br><br>
# <li>It contains advanced programming features such as generators and list comprehensions.<br><br>
# <li>Python's automatic memory management frees you from having to manually allocate and <br><br>         free memory in your code.<br><br>

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Arithmatic Opeartion</p><br>

# %%
2 + 3  #Addition
# Out:
# 5

# %%
45 - 25 #Subtraction
# Out:
# 20

# %%
2*25   #Multiplication
# Out:
# 50

# %%
45//5 #Integer Division
# Out:
# 9

# %%
45/8 #Floating point division
# Out:
# 5.625

# %%
23%7 #modulus
# Out:
# 2

# %%
divmod(9, 5) #calculate quotient and remainder
# Out:
# (1, 4)

# %%
2**10 #power
# Out:
# 1024

# %%
abs(7.4)
# Out:
# 7.4

# %%
abs(-5.6)
# Out:
# 5.6

# %%
#mixed operation
2*3 + 4//2 - 23*2 + 2**6
# Out:
# 26

# %%
#Let's try some big
34**45 + 98*898 - 987/23 + 2**123
# Out:
# 8.25184889837726e+68

# %%
#How big is integer
2**1000
# Out:
# 

# %%
#Try a little bigger
5**5000
# Out:
# ...

# %%
# Let's try a little more bigger
100**10000
# Out:
# ...

# %%
#use \ to continue to new line
2 + 7 * 23 / 3 * 90  \
+ 8 - 68
# Out:
# 4772.0

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# String</p><br>

# %%
'Anything in quote is treated as string.' #Quote can be single('') or double("")
# Out:
# 'Anything in quote is treated as string.'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Variables, Names, and Objects</p><br>

# %% [markdown]
# <h3>In Python, everything—booleans, integers, floats, strings, even large data
#     structures,functions, and programs—is implemented as an object.<br>
#
#
# An object is like a clear plastic box that contains a piece of data.The object
# has a type, such as boolean or integer, that determines what can be done with the data.
#
# Variable is  name that refer to values in the computer’s memory that we can define
# for use with our program. In Python, we use = to assign a value to a variable.

# %% [markdown]
# <h3>Variable names can only contain these characters:</h3>
# >Lowercase letters (a through z)<br>
# >Uppercase letters (A through Z)<br>
# >Digits (0 through 9)<br>
# >Underscore (_)<br>
# <p style="font-family: Arial; font-size:1.5em;color:blue; font-style:italic"><br>Names cannot begin with a digit. Also, Python treats names that begin with an underscore in special ways.</p>
#
# <p style="font-family: Arial; font-size:1.5em;color:red; font-style:italic"><br>Note: Python Reserved Keywords cannot be used as variable name.</p>
# These words are:<br>
# <table><th>False <th>class <th>finally <th>is <th>return<br>
# <th>None <th>continue <th>for <th>lambda <th>try<br>
# <th>True <th>def <th>from <th>nonlocal <th>while<br>
# <th>and <th>del <th>global <th>not <th>with<br>
# <th>as <th>elif <th>if <th>or <th>yield<br>
# <th>assert <th>else <th>import <th>pass<br>
# <th>break <th>except <th>in <th>raise<br>

# %%
a = 29
a
# Out:
# 29

# %%
b = 22
b
# Out:
# 22

# %%
c = a+b
c
# Out:
# 51

# %%
print(c)
# Out:
# 51

# %%
print(a+b)
# Out:
# 51

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# int

# %%
d = 4.5
print(a+d)
type(a+d)
# Out:
# 33.5
# float

# %%
type('abc')
# Out:
# str

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Numbers</p><br>
# <h3>A number can be Integer or Float value.

# %%
a = 97
print(a)
print(type(a))
# Out:
# 97
# <class 'int'>

# %%
b = 86.97
print(b)
print(type(b))
# Out:
# 86.97
# <class 'float'>

# %%
c  = 6
d = 7
print(c)
d
# Out:
# 6
# 7

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Swapping values of two numbers</p><br>

# %%
num1 = 34
num2 = 64

# %%
# In other language
temp = num1
num1 = num2
num2 = temp
print("After swapping values:")
print("num1 = ", num1)
print("num2 = ", num2)
# Out:
# After swapping values:
# num1 =  64
# num2 =  34

# %%
# In Python
num1, num2 = num2, num1
print("num1 = ", num1)
print("num2 = ", num2)
# Out:
# num1 =  34
# num2 =  64

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Short Hand Notation</p><br>

# %%
a = 63
a += 7 # equivalent to a = a + 7
a
# Out:
# 70

# %%
a /= 7  # equivalent to a = a / 7
a
# Out:
# 10.0

# %%
a %= 3 # # equivalent to a = a % 3
a
# Out:
# 1.0

# %%
b = 21
a += b # equivalent to a = a + b
a
# Out:
# 22.0

# %%
b += a # equivalent to b = b + a
b
# Out:
# 43.0

# %% [markdown]
# # Try these operations
# <h3>+=,  -=,  *=, /=,  //=, %=

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>
# Precedence</p><br>

# %%
2 + 3 * 4 #It follows the rule of BODMAS which we have learnt in primary Classes
# Out:
# 14

# %%
# Above expression is same as following
2 + (3 * 4)
# Out:
# 14

# %%
2 * 3 / 2 + 3 - 6 / 2 # This will print 3.0
# Out:
# 3.0

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>Bases</p><br>

# %% [markdown]
# <h2>In Python, we can express literal integers in three bases besides decimal:</h2>
# <h3>• 0b or 0B for binary (base 2).</h3>
# <h3>• 0o or 0O for octal (base 8).</h3>
# <h3>• 0x or 0X for hex (base 16).</h3>

# %%
a = 0b10 # a = 2
print(a)
c = 0b10010 
print(c)
# Out:
# 2
# 18

# %%
b = 0o71 # b = 57
b
# Out:
# 57

# %%
c = 0xAC  # c = 172
c
# Out:
# 172

# %%
d = 0xbc
d
# Out:
# 188

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>Type Conversion</p><br>

# %% [markdown]
# <b>To change other Python data types to an integer, use the int() function. This will keep
# the whole number and discard any fractional part.

# %%
int(True) # boolean to integer
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(98.6)  # Float to integer
# Out:
# 98

# %%
int(1.0e4)
# Out:
# 10000

# %%
int('99')  # string to integer
# Out:
# 99

# %%
int('-23')
# Out:
# -23

# %%
int('+12')
# Out:
# 12

# %%
int(12345) # Converting an integer to an integer doesn’t change anything but doesn’t hurt either
# Out:
# 12345

# %%
int('a') # convert something that doesn’t look like a number, you’ll get an exception
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-faf3bc21f5ca> in <module>()
# ----> 1 int('a') # convert something that doesn’t look like a number, you’ll get an exception
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
int('98.8') # gives an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-5f8096766429> in <module>()
# ----> 1 int('98.8') # gives an error
#
# ValueError: invalid literal for int() with base 10: '98.8'

# %%
float(True) # boolean to float
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(98) # integer to float
# Out:
# 98.0

# %%
float('99')  #string to float
# Out:
# 99.0

# %%
float('1.0e4')
# Out:
# 10000.0

# %%
float('a') # convert something that doesn’t look like a float, you’ll get an exception
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-3ef42889e3a4> in <module>()
# ----> 1 float('a') # convert something that doesn’t look like a float, you’ll get an exception
#
# ValueError: could not convert string to float: 'a'

# %% [markdown]
# <p style="font-family: Arial; font-size:3.75em;color:purple; font-style:bold"><br>String</p><br>
#
# Strings are immutable in python like other programming languages.

# %% [markdown]
# <h2>Create with Quotes

# %%
'python'
# Out:
# 'python'

# %%
"Anaconda"
# Out:
# 'Anaconda'

# %% [markdown]
# <h3>we can have single quotes inside double-quoted strings, or double quotes inside single-quoted strings:

# %%
a = " 'He said', His friend is ill."
print(a)
# Out:
#  'He said', His friend is ill.

# %%
'A "two by four" is actually 1 1⁄2" × 3 1⁄2".'
# Out:
# 'A "two by four" is actually 1 1⁄2" × 3 1⁄2".'

# %% [markdown]
# <h3>we can also use three single quotes (''') or three double quotes ("""):

# %%
'''Boom!'''
# Out:
# 'Boom!'

# %%
"""Eek!"""
# Out:
# 'Eek!'

# %% [markdown]
# <h3>Triple qoutes are most commonly used for multiline String.

# %%
poem = '''I do not like thee, Doctor Fell.
The reason why, I cannot tell.
But this I know, and know full well:
I do not like thee, Doctor Fell. '''

# %%
print(poem) # print() strips quotes from strings and prints their contents.
# Out:
# I do not like thee, Doctor Fell.
# The reason why, I cannot tell.
# But this I know, and know full well:
# I do not like thee, Doctor Fell.

# %%
poem  #There is difference b\w print() and console output, spend some time here to find them.
# Out:
# 'I do not like thee, Doctor Fell.\nThe reason why, I cannot tell.\nBut this I know, and know full well:\nI do not like thee, Doctor Fell. '

# %% [markdown]
# <h3><b> There is <i>empty string</i> in python, which has no characters at all but is perfectly valid

# %%
''
# Out:
# ''

# %%
""
# Out:
# ''

# %%
""""""
# Out:
# ''

# %% [markdown]
# # Convert Data Types by Using str()

# %%
str(98.6)
# Out:
# '98.6'

# %%
str(1.0e4)
# Out:
# '10000.0'

# %%
str(True)
# Out:
# 'True'

# %% [markdown]
# # Escape with \

# %%
palindrome = 'A man,\nA plan,\nA canal:\nPanama.' #\n used for nextline
print(palindrome)
# Out:
# A man,
# A plan,
# A canal:
# Panama.

# %%
print('a\tbc')  #\t used for tab
# Out:
# a	bc

# %%
testimony = "\"I did nothing!\" he said. \"Not that either! Or the other thing.\""   #\ escape immediate character
print(testimony)
# Out:
# "I did nothing!" he said. "Not that either! Or the other thing."

# %% [markdown]
# # Combine With +

# %%
'Release the kraken! ' + 'At once!'
# Out:
# 'Release the kraken! At once!'

# %% [markdown]
# <b>We can also combine literal strings (not string variables) just by having one after the other:

# %%
"My word! " "A gentleman caller!"
# Out:
# 'My word! A gentleman caller!'

# %%
a = 'Duck '
b = a
c = 'Go'
print(a+b+c)
# Out:
# Duck Duck Go

# %%
print(a, b, c)
# Out:
# Duck  Duck  Go

# %% [markdown]
# # Duplicate with *

# %%
start = 'Apple '*4  + '\n'
middle = 'Sandwitch '*5 + '\n'
end = 'Bread '*3  + '\n'
print(start, middle, end)
# Out:
# Apple Apple Apple Apple
#  Sandwitch Sandwitch Sandwitch Sandwitch Sandwitch
#  Bread Bread Bread

# %%
sher_khan = 'Hazrat '
print(sher_khan*3)
# Out:
# Hazrat Hazrat Hazrat

# %% [markdown]
# # Extract a Character with []

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[0]
# Out:
# 'a'

# %%
letters[4]
# Out:
# 'e'

# %%
letters[9]
# Out:
# 'j'

# %%
letters[14]
# Out:
# 'o'

# %%
letters[19]
# Out:
# 't'

# %%
letters[25]
# Out:
# 'z'

# %%
letters[26] # Gives an exception
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-97-c3388359e600> in <module>()
# ----> 1 letters[26] # Gives an exception
#
# IndexError: string index out of range

# %% [markdown]
# Because strings are immutable, we can’t insert a character directly into one or change
# the character at a specific index.

# %%
a = 'Henny'

# %%
a[0] = 'P' # It raise an error.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-7e2b696a0fb7> in <module>()
# ----> 1 a[0] = 'P' # It raise an error.
#
# TypeError: 'str' object does not support item assignment

# %%
# But we can use replace() function to replace a value in String
a.replace('H', 'P')
# Out:
# 'Penny'

# %%
#But still a remain 'Henny'
a
# Out:
# 'Henny'

# %%
# To change it to 'Penny' do
a = a.replace('H', 'P')
a
# Out:
# 'Penny'

# %%
#or
a = 'P' + a[1:]
a
# Out:
# 'Penny'

# %% [markdown]
# # Slice with [ start : end : step ]

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[::]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[20:]
# Out:
# 'uvwxyz'

# %%
letters[-1::-1] #reverse string
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %%
letters[::-1] #This gives the same result as above
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %%
letters[::2] # it escape every one character
# Out:
# 'acegikmoqsuwy'

# %% [markdown]
# # Get Length with len()

# %%
len(letters)
# Out:
# 26

# %%
empty = ''
len(empty)
# Out:
# 0

# %% [markdown]
# # Split with split()

# %%
todos = 'get gloves,get mask,give cat vitamins,call ambulance'
todos.split(',') # Split todos if ','
# Out:
# ['get gloves', 'get mask', 'give cat vitamins', 'call ambulance']

# %%
todos.split() # split todos  if space (' ')
# Out:
# ['get', 'gloves,get', 'mask,give', 'cat', 'vitamins,call', 'ambulance']

# %% [markdown]
# # Combine with join()

# %%
crypto_list = ['Yeti', 'Bigfoot', 'Loch Ness Monster']
crypto_string = ', '.join(crypto_list)
print('Found and signing book deals:', crypto_string)
# Out:
# Found and signing book deals: Yeti, Bigfoot, Loch Ness Monster

# %% [markdown]
# # Playing with Strings

# %%
poem = '''All that doth flow we cannot liquid name
Or else would fire and water be the same;
But that is liquid which is moist and wet
Fire that property can never get.
Then 'tis not cold that doth the fire put out
But 'tis the wet that makes it die, no doubt.'''

# %%
poem[:13]
print(len(poem[:13]))
# Out:
# 13

# %%
len(poem)
# Out:
# 250

# %%
poem.startswith('All')
# Out:
# True

# %%
poem.endswith('That\'s all, folks!')
# Out:
# False

# %%
word = 'the'
poem.find(word)
# Out:
# 73

# %%
poem.rfind(word)
# Out:
# 214

# %%
poem.count(word)
# Out:
# 3

# %%
poem.isalnum()
# Out:
# False
